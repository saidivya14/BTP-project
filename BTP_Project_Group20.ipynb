# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/BTP_Project'
# Out:
# /content/drive/MyDrive/Colab Notebooks/BTP_Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv('rainfall dataset/rainfall in india 1901-2015.csv')
data = data.fillna(data.mean())
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4116 non-null   float64
#  3   FEB          4116 non-null   float64
#  4   MAR          4116 non-null   float64
#  5   APR          4116 non-null   float64
#  6   MAY          4116 non-null   float64
#  7   JUN          4116 non-null   float64
#  8   JUL          4116 non-null   float64
#  9   AUG          4116 non-null   float64
#  10  SEP          4116 non-null   float64
#  11  OCT          4116 non-null   float64
#  12  NOV          4116 non-null   float64
#  13  DEC          4116 non-null   float64
#  14  ANNUAL       4116 non-null   float64
#  15  Jan-Feb      4116 non-null   float64
#  16  Mar-May      4116 non-null   float64
#  17  Jun-Sep      4116 non-null   float64
#  18  Oct-Dec      4116 non-null   float64
# dtypes: float64(17), int64(1), object(1)
# memory usage: 611.1+ KB

# %%
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN  ...  Mar-May  Jun-Sep  Oct-Dec
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2  ...    560.3   1696.3    980.3
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  ...    458.3   2185.9    716.7
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  ...    236.1   1874.0    690.6
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4  ...    506.9   1977.6    571.0
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3  ...    309.7   1624.9    630.8
#
# [5 rows x 19 columns]

# %%
data.describe()
# Out:
#               YEAR          JAN  ...      Jun-Sep      Oct-Dec
# count  4116.000000  4116.000000  ...  4116.000000  4116.000000
# mean   1958.218659    18.957320  ...  1064.724769   154.100487
# std      33.140898    33.569044  ...   706.881054   166.678751
# min    1901.000000     0.000000  ...    57.400000     0.000000
# 25%    1930.000000     0.600000  ...   574.375000    34.200000
# 50%    1958.000000     6.000000  ...   882.250000    98.800000
# 75%    1987.000000    22.125000  ...  1287.550000   212.600000
# max    2015.000000   583.700000  ...  4536.900000  1252.500000
#
# [8 rows x 18 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import numpy as np
division_data = np.asarray(data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL','AUG', 'SEP', 'OCT', 'NOV', 'DEC']])

X = None; y = None
for i in range(division_data.shape[1]-3):
    if X is None:
        X = division_data[:, i:i+3]
        y = division_data[:, i+3]
    else:
        X = np.concatenate((X, division_data[:, i:i+3]), axis=0)
        y = np.concatenate((y, division_data[:, i+3]), axis=0)
        
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn import linear_model
# linear model
reg = linear_model.ElasticNet(alpha=0.5)
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
print(mean_absolute_error(y_test, y_pred))
print(math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 93.38359716703492
# 142.59909822797266

# %%
from sklearn.svm import SVR
# SVM model
clf = SVR(kernel='rbf', gamma='auto', C=0.5, epsilon=0.2)
clf.fit(X_train, y_train) 
y_pred = clf.predict(X_test)
print(mean_absolute_error(y_test, y_pred))
print(math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 123.24870195644858
# 199.7595311103537

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
# Randomforest model
regressor = RandomForestRegressor(n_estimators=20, random_state=0)
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test)
print(mean_absolute_error(y_test, y_pred))
print(math.sqrt(mean_squared_error(y_test, y_pred)))

# %%
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
lasso = linear_model.Lasso(alpha=0.1)
lasso.fit(X_train, y_train) 
y_pred = lasso.predict(X_test)
print(mean_absolute_error(y_test, y_pred))
print(math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 93.38350394849435
# 142.599200639446

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train) 
y_pred = ridge.predict(X_test)
print(mean_absolute_error(y_test, y_pred))
print(math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3d008375be41> in <module>()
#       2 from sklearn.metrics import mean_absolute_error
#       3 ridge = Ridge(alpha=1.0)
# ----> 4 ridge.fit(X_train, y_train)
#       5 y_pred = ridge.predict(X_test)
#       6 print(mean_absolute_error(y_test, y_pred))
#
# NameError: name 'X_train' is not defined

# %%
from keras.models import Model
from keras.layers import Dense, Input, Conv1D, Flatten
# NN model
inputs = Input(shape=(3,1))
x = Conv1D(64, 2, padding='same', activation='elu')(inputs)
x = Conv1D(128, 2, padding='same', activation='elu')(x)
x = Flatten()(x)
x = Dense(128, activation='elu')(x)
x = Dense(64, activation='elu')(x)
x = Dense(32, activation='elu')(x)
x = Dense(1, activation='linear')(x)
model = Model(inputs=[inputs], outputs=[x])
model.compile(loss='mean_squared_error', optimizer='adamax', metrics=['mae'])
model.summary()
model.fit(x=np.expand_dims(X_train, axis=2), y=y_train, batch_size=64, epochs=10, verbose=1, validation_split=0.1, shuffle=True)
y_pred = model.predict(np.expand_dims(X_test, axis=2))
print (mean_absolute_error(y_test, y_pred))
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 3, 64)             192
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 3, 128)            16512
# _________________________________________________________________
# flatten (Flatten)            (None, 384)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               49280
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 417/417 [==============================] - 3s 7ms/step - loss: 24317.0762 - mae: 94.4014 - val_loss: 18328.7520 - val_mae: 87.0536
# Epoch 2/10
# 417/417 [==============================] - 2s 5ms/step - loss: 20158.3130 - mae: 89.7514 - val_loss: 18786.7480 - val_mae: 84.5499
# Epoch 3/10
# 417/417 [==============================] - 2s 5ms/step - loss: 18563.9435 - mae: 87.1717 - val_loss: 18294.3301 - val_mae: 89.0495
# Epoch 4/10
# 417/417 [==============================] - 2s 5ms/step - loss: 18447.8549 - mae: 86.9353 - val_loss: 18601.2930 - val_mae: 88.5138
# Epoch 5/10
# 417/417 [==============================] - 2s 5ms/step - loss: 17732.7155 - mae: 85.6507 - val_loss: 18971.0098 - val_mae: 91.1789
# Epoch 6/10
# 417/417 [==============================] - 2s 5ms/step - loss: 18126.9727 - mae: 85.6711 - val_loss: 18426.8496 - val_mae: 89.5390
# Epoch 7/10
# 417/417 [==============================] - 2s 5ms/step - loss: 18806.6846 - mae: 87.0954 - val_loss: 18139.4316 - val_mae: 86.6783
# Epoch 8/10
# 417/417 [==============================] - 2s 5ms/step - loss: 18746.4095 - mae: 86.5616 - val_loss: 17969.5488 - val_mae: 85.7451
# Epoch 9/10
# 417/417 [==============================] - 2s 5ms/step - loss: 18006.1847 - mae: 85.0417 - val_loss: 18854.1895 - val_mae: 91.0266
# Epoch 10/10
# 417/417 [==============================] - 2s 5ms/step - loss: 17980.9118 - mae: 85.1745 - val_loss: 17902.2988 - val_mae: 84.6120
# 82.70339551800089

# %%
data = pd.read_csv('rainfall dataset/rainfall in india 1901-2015.csv')
data = data.fillna(data.median())
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4116 non-null   float64
#  3   FEB          4116 non-null   float64
#  4   MAR          4116 non-null   float64
#  5   APR          4116 non-null   float64
#  6   MAY          4116 non-null   float64
#  7   JUN          4116 non-null   float64
#  8   JUL          4116 non-null   float64
#  9   AUG          4116 non-null   float64
#  10  SEP          4116 non-null   float64
#  11  OCT          4116 non-null   float64
#  12  NOV          4116 non-null   float64
#  13  DEC          4116 non-null   float64
#  14  ANNUAL       4116 non-null   float64
#  15  Jan-Feb      4116 non-null   float64
#  16  Mar-May      4116 non-null   float64
#  17  Jun-Sep      4116 non-null   float64
#  18  Oct-Dec      4116 non-null   float64
# dtypes: float64(17), int64(1), object(1)
# memory usage: 611.1+ KB

# %%
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN  ...  Mar-May  Jun-Sep  Oct-Dec
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2  ...    560.3   1696.3    980.3
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  ...    458.3   2185.9    716.7
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  ...    236.1   1874.0    690.6
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4  ...    506.9   1977.6    571.0
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3  ...    309.7   1624.9    630.8
#
# [5 rows x 19 columns]

# %%
data.describe()
# Out:
#               YEAR          JAN  ...      Jun-Sep      Oct-Dec
# count  4116.000000  4116.000000  ...  4116.000000  4116.000000
# mean   1958.218659    18.944728  ...  1064.278644   153.923931
# std      33.140898    33.571472  ...   706.938870   166.708269
# min    1901.000000     0.000000  ...    57.400000     0.000000
# 25%    1930.000000     0.600000  ...   574.375000    34.200000
# 50%    1958.000000     6.000000  ...   881.100000    98.200000
# 75%    1987.000000    22.125000  ...  1287.550000   212.600000
# max    2015.000000   583.700000  ...  4536.900000  1252.500000
#
# [8 rows x 18 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import numpy as np
division_data = np.asarray(data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL','AUG', 'SEP', 'OCT', 'NOV', 'DEC']])

X = None; y = None
for i in range(division_data.shape[1]-3):
    if X is None:
        X = division_data[:, i:i+3]
        y = division_data[:, i+3]
    else:
        X = np.concatenate((X, division_data[:, i:i+3]), axis=0)
        y = np.concatenate((y, division_data[:, i+3]), axis=0)
        
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn import linear_model
# linear model
reg = linear_model.ElasticNet(alpha=0.5)
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
print(mean_absolute_error(y_test, y_pred))
# Out:
# 92.74958342312478

# %%
from sklearn.svm import SVR
# SVM model
clf = SVR(kernel='rbf', gamma='auto', C=0.5, epsilon=0.2)
clf.fit(X_train, y_train) 
y_pred = clf.predict(X_test)
print(mean_absolute_error(y_test, y_pred))
# Out:
# 124.2843503655669

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
# Randomforest model
regressor = RandomForestRegressor(n_estimators=20, random_state=0)
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test)
print (mean_absolute_error(y_test, y_pred))
# Out:
# 90.24311777249783

# %%
from keras.models import Model
from keras.layers import Dense, Input, Conv1D, Flatten
# NN model
inputs = Input(shape=(3,1))
x = Conv1D(64, 2, padding='same', activation='elu')(inputs)
x = Conv1D(128, 2, padding='same', activation='elu')(x)
x = Flatten()(x)
x = Dense(128, activation='elu')(x)
x = Dense(64, activation='elu')(x)
x = Dense(32, activation='elu')(x)
x = Dense(1, activation='linear')(x)
model = Model(inputs=[inputs], outputs=[x])
model.compile(loss='mean_squared_error', optimizer='adamax', metrics=['mae'])
model.summary()
model.fit(x=np.expand_dims(X_train, axis=2), y=y_train, batch_size=64, epochs=10, verbose=1, validation_split=0.1, shuffle=True)
y_pred = model.predict(np.expand_dims(X_test, axis=2))
print (mean_absolute_error(y_test, y_pred))
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 3, 64)             192
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 3, 128)            16512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               49280
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 417/417 [==============================] - 3s 5ms/step - loss: 24426.4029 - mae: 94.0061 - val_loss: 18074.3867 - val_mae: 85.1797
# Epoch 2/10
# 417/417 [==============================] - 2s 4ms/step - loss: 18926.5558 - mae: 87.9316 - val_loss: 18013.5195 - val_mae: 82.7401
# Epoch 3/10
# 417/417 [==============================] - 2s 4ms/step - loss: 18846.1612 - mae: 86.9506 - val_loss: 18451.7383 - val_mae: 87.7859
# Epoch 4/10
# 417/417 [==============================] - 2s 5ms/step - loss: 18619.3719 - mae: 87.0762 - val_loss: 17888.3848 - val_mae: 83.4497
# Epoch 5/10
# 417/417 [==============================] - 2s 4ms/step - loss: 18310.7845 - mae: 85.9156 - val_loss: 17795.3379 - val_mae: 83.9175
# Epoch 6/10
# 417/417 [==============================] - 2s 4ms/step - loss: 18398.3619 - mae: 86.0936 - val_loss: 17913.8613 - val_mae: 83.4383
# Epoch 7/10
# 417/417 [==============================] - 2s 4ms/step - loss: 18919.6984 - mae: 86.6008 - val_loss: 17839.6660 - val_mae: 84.4943
# Epoch 8/10
# 417/417 [==============================] - 2s 4ms/step - loss: 18103.6346 - mae: 85.8175 - val_loss: 18122.2559 - val_mae: 84.6265
# Epoch 9/10
# 417/417 [==============================] - 2s 4ms/step - loss: 18339.3042 - mae: 85.7939 - val_loss: 18268.5742 - val_mae: 86.8927
# Epoch 10/10
# 417/417 [==============================] - 2s 4ms/step - loss: 19016.1599 - mae: 87.2913 - val_loss: 17786.3945 - val_mae: 82.2096
# 84.01653446859636

# %%
data = pd.read_csv('rainfall dataset/rainfall in india 1901-2015.csv')
data = data.fillna(method ='pad')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4116 non-null   float64
#  3   FEB          4116 non-null   float64
#  4   MAR          4116 non-null   float64
#  5   APR          4116 non-null   float64
#  6   MAY          4116 non-null   float64
#  7   JUN          4116 non-null   float64
#  8   JUL          4116 non-null   float64
#  9   AUG          4116 non-null   float64
#  10  SEP          4116 non-null   float64
#  11  OCT          4116 non-null   float64
#  12  NOV          4116 non-null   float64
#  13  DEC          4116 non-null   float64
#  14  ANNUAL       4116 non-null   float64
#  15  Jan-Feb      4116 non-null   float64
#  16  Mar-May      4116 non-null   float64
#  17  Jun-Sep      4116 non-null   float64
#  18  Oct-Dec      4116 non-null   float64
# dtypes: float64(17), int64(1), object(1)
# memory usage: 611.1+ KB

# %%
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN  ...  Mar-May  Jun-Sep  Oct-Dec
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2  ...    560.3   1696.3    980.3
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  ...    458.3   2185.9    716.7
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  ...    236.1   1874.0    690.6
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4  ...    506.9   1977.6    571.0
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3  ...    309.7   1624.9    630.8
#
# [5 rows x 19 columns]

# %%
data.describe()
# Out:
#               YEAR          JAN  ...      Jun-Sep      Oct-Dec
# count  4116.000000  4116.000000  ...  4116.000000  4116.000000
# mean   1958.218659    18.957240  ...  1065.552114   154.957070
# std      33.140898    33.576192  ...   707.840186   167.807169
# min    1901.000000     0.000000  ...    57.400000     0.000000
# 25%    1930.000000     0.600000  ...   574.375000    34.200000
# 50%    1958.000000     6.000000  ...   881.750000    98.800000
# 75%    1987.000000    22.200000  ...  1291.125000   215.775000
# max    2015.000000   583.700000  ...  4536.900000  1252.500000
#
# [8 rows x 18 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import numpy as np
division_data = np.asarray(data[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL','AUG', 'SEP', 'OCT', 'NOV', 'DEC']])

X = None; y = None
for i in range(division_data.shape[1]-3):
    if X is None:
        X = division_data[:, i:i+3]
        y = division_data[:, i+3]
    else:
        X = np.concatenate((X, division_data[:, i:i+3]), axis=0)
        y = np.concatenate((y, division_data[:, i+3]), axis=0)
        
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn import linear_model
# linear model
reg = linear_model.ElasticNet(alpha=0.5)
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
print(mean_absolute_error(y_test, y_pred))
# Out:
# 92.96564022983333

# %%
from sklearn.svm import SVR
# SVM model
clf = SVR(kernel='rbf', gamma='auto', C=0.5, epsilon=0.2)
clf.fit(X_train, y_train) 
y_pred = clf.predict(X_test)
print(mean_absolute_error(y_test, y_pred))
# Out:
# 123.63711164690694

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
# Randomforest model
regressor = RandomForestRegressor(n_estimators=20, random_state=0)
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test)
print (mean_absolute_error(y_test, y_pred))
# Out:
# 90.57984491306881

# %%
from keras.models import Model
from keras.layers import Dense, Input, Conv1D, Flatten
# NN model
inputs = Input(shape=(3,1))
x = Conv1D(64, 2, padding='same', activation='elu')(inputs)
x = Conv1D(128, 2, padding='same', activation='elu')(x)
x = Flatten()(x)
x = Dense(128, activation='elu')(x)
x = Dense(64, activation='elu')(x)
x = Dense(32, activation='elu')(x)
x = Dense(1, activation='linear')(x)
model = Model(inputs=[inputs], outputs=[x])
model.compile(loss='mean_squared_error', optimizer='adamax', metrics=['mae'])
model.summary()
model.fit(x=np.expand_dims(X_train, axis=2), y=y_train, batch_size=64, epochs=10, verbose=1, validation_split=0.1, shuffle=True)
y_pred = model.predict(np.expand_dims(X_test, axis=2))
print (mean_absolute_error(y_test, y_pred))
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 3, 64)             192
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 3, 128)            16512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               49280
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 417/417 [==============================] - 3s 5ms/step - loss: 24435.9808 - mae: 95.0419 - val_loss: 20626.0371 - val_mae: 88.9167
# Epoch 2/10
# 417/417 [==============================] - 2s 5ms/step - loss: 18262.7826 - mae: 86.6995 - val_loss: 20299.2266 - val_mae: 91.0804
# Epoch 3/10
# 417/417 [==============================] - 2s 5ms/step - loss: 17302.1973 - mae: 84.0522 - val_loss: 20129.5820 - val_mae: 90.3236
# Epoch 4/10
# 417/417 [==============================] - 2s 5ms/step - loss: 17947.4221 - mae: 85.2197 - val_loss: 20076.2520 - val_mae: 89.5402
# Epoch 5/10
# 417/417 [==============================] - 2s 5ms/step - loss: 17418.2036 - mae: 85.0805 - val_loss: 20010.8457 - val_mae: 89.7275
# Epoch 6/10
# 417/417 [==============================] - 2s 5ms/step - loss: 17723.2424 - mae: 84.2925 - val_loss: 19874.0762 - val_mae: 88.6805
# Epoch 7/10
# 417/417 [==============================] - 2s 5ms/step - loss: 17301.0604 - mae: 83.7152 - val_loss: 19961.6406 - val_mae: 90.1307
# Epoch 8/10
# 417/417 [==============================] - 2s 5ms/step - loss: 18261.5575 - mae: 84.6785 - val_loss: 19830.9492 - val_mae: 89.3367
# Epoch 9/10
# 417/417 [==============================] - 2s 5ms/step - loss: 18398.6840 - mae: 86.1908 - val_loss: 19755.9609 - val_mae: 87.2563
# Epoch 10/10
# 417/417 [==============================] - 2s 5ms/step - loss: 17881.0657 - mae: 84.9111 - val_loss: 19779.6152 - val_mae: 90.8279
# 89.86318143466916

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import numpy as np
data = pd.read_csv('rainfall dataset/rainfall in india 1901-2015.csv')
data = data.fillna(data.mean())
subdivs = data['SUBDIVISION'].unique()
mean_error = []
for i in subdivs:
  df1 = data[data['SUBDIVISION']==i]
  division_data = np.asarray(df1[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL','AUG', 'SEP', 'OCT', 'NOV', 'DEC']])

  X = None; y = None
  for i in range(division_data.shape[1]-3):
      if X is None:
          X = division_data[:, i:i+3]
          y = division_data[:, i+3]
      else:
          X = np.concatenate((X, division_data[:, i:i+3]), axis=0)
          y = np.concatenate((y, division_data[:, i+3]), axis=0)
          
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
  from keras.models import Model
  from keras.layers import Dense, Input, Conv1D, Flatten
  # NN model
  inputs = Input(shape=(3,1))
  x = Conv1D(64, 2, padding='same', activation='relu')(inputs)
  x = Conv1D(128, 2, padding='same', activation='relu')(x)
  x = Flatten()(x)
  x = Dense(128, activation='relu')(x)
  x = Dense(64, activation='relu')(x)
  x = Dense(32, activation='relu')(x)
  x = Dense(1, activation='linear')(x)
  model = Model(inputs=[inputs], outputs=[x])
  model.compile(loss='mean_squared_error', optimizer='adamax', metrics=['mae'])
  model.summary()
  model.fit(x=np.expand_dims(X_train, axis=2), y=y_train, batch_size=64, epochs=10, verbose=1, validation_split=0.1, shuffle=True)
  y_pred = model.predict(np.expand_dims(X_test, axis=2))
  p = mean_absolute_error(y_test, y_pred)
  mean_error.append(p)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 3, 64)             192
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 3, 128)            16512
# _________________________________________________________________
# flatten (Flatten)            (None, 384)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               49280
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 49ms/step - loss: 79424.4612 - mae: 224.0012 - val_loss: 39356.3828 - val_mae: 157.4513
# Epoch 2/10
# 12/12 [==============================] - 0s 10ms/step - loss: 44648.7611 - mae: 163.4912 - val_loss: 44329.9922 - val_mae: 157.9360
# Epoch 3/10
# 12/12 [==============================] - 0s 8ms/step - loss: 42765.3308 - mae: 157.5562 - val_loss: 40214.7109 - val_mae: 152.5604
# Epoch 4/10
# 12/12 [==============================] - 0s 10ms/step - loss: 45604.9261 - mae: 164.6905 - val_loss: 41486.6641 - val_mae: 153.3343
# Epoch 5/10
# 12/12 [==============================] - 0s 8ms/step - loss: 40355.1641 - mae: 155.8438 - val_loss: 42482.9609 - val_mae: 154.9138
# Epoch 6/10
# 12/12 [==============================] - 0s 10ms/step - loss: 40586.1013 - mae: 155.0680 - val_loss: 41218.9141 - val_mae: 153.1985
# Epoch 7/10
# 12/12 [==============================] - 0s 10ms/step - loss: 46097.5652 - mae: 164.2057 - val_loss: 42477.5078 - val_mae: 154.7007
# Epoch 8/10
# 12/12 [==============================] - 0s 8ms/step - loss: 40888.1382 - mae: 157.6516 - val_loss: 41792.4453 - val_mae: 153.7288
# Epoch 9/10
# 12/12 [==============================] - 0s 9ms/step - loss: 40042.3753 - mae: 152.5460 - val_loss: 41820.9922 - val_mae: 153.6871
# Epoch 10/10
# 12/12 [==============================] - 0s 9ms/step - loss: 39118.2867 - mae: 151.7078 - val_loss: 42272.9922 - val_mae: 154.2150
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 3, 64)             192
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 3, 128)            16512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               49280
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 10/10 [==============================] - 1s 28ms/step - loss: 173792.1463 - mae: 302.7937 - val_loss: 100896.8125 - val_mae: 214.4498
# Epoch 2/10
# 10/10 [==============================] - 0s 9ms/step - loss: 88707.7869 - mae: 218.2155 - val_loss: 89511.6719 - val_mae: 200.4259
# Epoch 3/10
# 10/10 [==============================] - 0s 9ms/step - loss: 76444.1463 - mae: 199.0019 - val_loss: 95796.4531 - val_mae: 188.7370
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               49280
# _________________________________________________________________
# dense_21 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 24ms/step - loss: 35278.2976 - mae: 139.6436 - val_loss: 27553.2285 - val_mae: 126.7834
# Epoch 2/10
# 12/12 [==============================] - 0s 10ms/step - loss: 22733.1463 - mae: 113.0424 - val_loss: 15118.8584 - val_mae: 98.9786
# Epoch 3/10
# 12/12 [==============================] - 0s 9ms/step - loss: 16856.3337 - mae: 101.6238 - val_loss: 13744.2910 - val_mae: 87.4824
# Epoch 4/10
# 12/12 [==============================] - 0s 10ms/step - loss: 15124.8803 - mae: 90.1281 - val_loss: 12094.2578 - val_mae: 85.5182
# Epoch 5/10
# 12/12 [==============================] - 0s 8ms/step - loss: 14061.9038 - mae: 87.4773 - val_loss: 11805.6289 - val_mae: 84.7845
# Epoch 6/10
# 12/12 [==============================] - 0s 8ms/step - loss: 12809.5886 - mae: 80.7252 - val_loss: 11782.3701 - val_mae: 82.6895
# Epoch 7/10
# 12/12 [==============================] - 0s 8ms/step - loss: 13688.8052 - mae: 82.6928 - val_loss: 11794.5332 - val_mae: 82.7084
# Epoch 8/10
# 12/12 [==============================] - 0s 7ms/step - loss: 11951.9205 - mae: 76.5853 - val_loss: 11837.6465 - val_mae: 83.6894
# Epoch 9/10
# 12/12 [==============================] - 0s 9ms/step - loss: 13113.1948 - mae: 79.0939 - val_loss: 11929.7109 - val_mae: 82.3769
# Epoch 10/10
# 12/12 [==============================] - 0s 8ms/step - loss: 12396.3366 - mae: 77.3239 - val_loss: 11942.6914 - val_mae: 84.0652
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 128)               49280
# _________________________________________________________________
# dense_25 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_26 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 25ms/step - loss: 32109.9483 - mae: 129.2649 - val_loss: 13327.8271 - val_mae: 87.2761
# Epoch 2/10
# 12/12 [==============================] - 0s 8ms/step - loss: 16891.3058 - mae: 98.5522 - val_loss: 10109.5684 - val_mae: 72.4528
# Epoch 3/10
# 12/12 [==============================] - 0s 10ms/step - loss: 14672.1434 - mae: 84.4549 - val_loss: 9198.6943 - val_mae: 70.0995
# Epoch 4/10
# 12/12 [==============================] - 0s 9ms/step - loss: 12761.8148 - mae: 79.8310 - val_loss: 10384.8428 - val_mae: 76.1417
# Epoch 5/10
# 12/12 [==============================] - 0s 8ms/step - loss: 12517.4478 - mae: 77.9095 - val_loss: 9058.9248 - val_mae: 68.2411
# Epoch 6/10
# 12/12 [==============================] - 0s 9ms/step - loss: 12073.4889 - mae: 74.8784 - val_loss: 9253.3643 - val_mae: 69.7710
# Epoch 7/10
# 12/12 [==============================] - 0s 9ms/step - loss: 11358.5758 - mae: 72.7216 - val_loss: 9254.7529 - val_mae: 69.7592
# Epoch 8/10
# 12/12 [==============================] - 0s 9ms/step - loss: 12966.7521 - mae: 78.2932 - val_loss: 9083.2256 - val_mae: 68.1398
# Epoch 9/10
# 12/12 [==============================] - 0s 10ms/step - loss: 12184.0864 - mae: 75.4558 - val_loss: 9829.4746 - val_mae: 71.7983
# Epoch 10/10
# 12/12 [==============================] - 0s 10ms/step - loss: 11553.1588 - mae: 72.8312 - val_loss: 8878.3105 - val_mae: 67.7319
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 128)               49280
# _________________________________________________________________
# dense_29 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_30 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_31 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 23ms/step - loss: 25219.3099 - mae: 110.0231 - val_loss: 12300.3672 - val_mae: 80.3260
# Epoch 2/10
# 12/12 [==============================] - 0s 9ms/step - loss: 16574.0925 - mae: 95.0387 - val_loss: 9516.8574 - val_mae: 64.1335
# Epoch 3/10
# 12/12 [==============================] - 0s 8ms/step - loss: 13141.6681 - mae: 78.9157 - val_loss: 8655.7129 - val_mae: 60.3080
# Epoch 4/10
# 12/12 [==============================] - 0s 10ms/step - loss: 11460.8963 - mae: 70.4846 - val_loss: 8631.7598 - val_mae: 59.9079
# Epoch 5/10
# 12/12 [==============================] - 0s 8ms/step - loss: 11626.8200 - mae: 70.4660 - val_loss: 8474.0684 - val_mae: 59.7872
# Epoch 6/10
# 12/12 [==============================] - 0s 8ms/step - loss: 12944.2053 - mae: 74.6342 - val_loss: 8510.4326 - val_mae: 59.7014
# Epoch 7/10
# 12/12 [==============================] - 0s 8ms/step - loss: 10934.2988 - mae: 69.5318 - val_loss: 8347.5742 - val_mae: 59.5691
# Epoch 8/10
# 12/12 [==============================] - 0s 9ms/step - loss: 10702.0623 - mae: 67.3926 - val_loss: 8337.9180 - val_mae: 59.7410
# Epoch 9/10
# 12/12 [==============================] - 0s 9ms/step - loss: 10787.5838 - mae: 68.3572 - val_loss: 8415.8652 - val_mae: 59.4757
# Epoch 10/10
# 12/12 [==============================] - 0s 8ms/step - loss: 12207.5138 - mae: 73.2382 - val_loss: 8276.9092 - val_mae: 59.6016
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               49280
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_34 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 384)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 128)               49280
# _________________________________________________________________
# dense_41 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_42 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_43 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 26ms/step - loss: 16597.4100 - mae: 79.0818 - val_loss: 9086.3164 - val_mae: 59.0724
# Epoch 2/10
# 12/12 [==============================] - 0s 10ms/step - loss: 10726.9534 - mae: 65.4339 - val_loss: 8197.8145 - val_mae: 52.3485
# Epoch 3/10
# 12/12 [==============================] - 0s 9ms/step - loss: 7286.1144 - mae: 51.0458 - val_loss: 7773.9775 - val_mae: 51.2384
# Epoch 4/10
# 12/12 [==============================] - 0s 10ms/step - loss: 7949.3024 - mae: 52.2361 - val_loss: 7623.7656 - val_mae: 51.5387
# Epoch 5/10
# 12/12 [==============================] - 0s 8ms/step - loss: 8497.5669 - mae: 55.7420 - val_loss: 7836.6602 - val_mae: 51.3721
# Epoch 6/10
# 12/12 [==============================] - 0s 8ms/step - loss: 8459.3033 - mae: 55.0193 - val_loss: 7478.0015 - val_mae: 51.2221
# Epoch 7/10
# 12/12 [==============================] - 0s 11ms/step - loss: 8865.5979 - mae: 55.6977 - val_loss: 7488.0190 - val_mae: 50.9214
# Epoch 8/10
# 12/12 [==============================] - 0s 9ms/step - loss: 9617.4443 - mae: 58.9175 - val_loss: 7529.9365 - val_mae: 50.2862
# Epoch 9/10
# 12/12 [==============================] - 0s 10ms/step - loss: 7930.4158 - mae: 52.3910 - val_loss: 7333.4878 - val_mae: 50.4281
# Epoch 10/10
# 12/12 [==============================] - 0s 9ms/step - loss: 8342.2835 - mae: 54.7805 - val_loss: 7446.1587 - val_mae: 50.1490
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 384)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 128)               49280
# _________________________________________________________________
# dense_45 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_46 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_47 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 27ms/step - loss: 36940.0376 - mae: 127.4257 - val_loss: 27656.3125 - val_mae: 117.5826
# Epoch 2/10
# 12/12 [==============================] - 0s 8ms/step - loss: 23445.1471 - mae: 109.3128 - val_loss: 23568.0020 - val_mae: 107.4216
# Epoch 3/10
# 12/12 [==============================] - 0s 8ms/step - loss: 18750.0847 - mae: 95.3690 - val_loss: 21321.3906 - val_mae: 97.6717
# Epoch 4/10
# 12/12 [==============================] - 0s 10ms/step - loss: 15945.0605 - mae: 84.9397 - val_loss: 20612.2598 - val_mae: 96.4741
# Epoch 5/10
# 12/12 [==============================] - 0s 9ms/step - loss: 14594.4115 - mae: 79.9407 - val_loss: 20787.5078 - val_mae: 95.2588
# Epoch 6/10
# 12/12 [==============================] - 0s 11ms/step - loss: 15357.3060 - mae: 79.4879 - val_loss: 20385.4316 - val_mae: 94.5086
# Epoch 7/10
# 12/12 [==============================] - 0s 8ms/step - loss: 14190.2070 - mae: 78.4895 - val_loss: 20540.8027 - val_mae: 94.2385
# Epoch 8/10
# 12/12 [==============================] - 0s 8ms/step - loss: 15481.3862 - mae: 82.8571 - val_loss: 20284.7324 - val_mae: 93.7125
# Epoch 9/10
# 12/12 [==============================] - 0s 9ms/step - loss: 16176.6953 - mae: 84.3884 - val_loss: 20671.9453 - val_mae: 94.4468
# Epoch 10/10
# 12/12 [==============================] - 0s 9ms/step - loss: 14573.8405 - mae: 78.4530 - val_loss: 20413.5449 - val_mae: 93.5935
# Model: "model_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_24 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 384)               0
# _________________________________________________________________
# dense_48 (Dense)             (None, 128)               49280
# _________________________________________________________________
# dense_49 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_50 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_51 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 25ms/step - loss: 7029.1095 - mae: 49.4958 - val_loss: 6295.9927 - val_mae: 52.8450
# Epoch 2/10
# 12/12 [==============================] - 0s 10ms/step - loss: 5405.9907 - mae: 45.2865 - val_loss: 6234.9795 - val_mae: 49.6879
# Epoch 3/10
# 12/12 [==============================] - 0s 10ms/step - loss: 5402.5477 - mae: 42.5203 - val_loss: 5854.8623 - val_mae: 48.8180
# Epoch 4/10
# 12/12 [==============================] - 0s 10ms/step - loss: 4329.9839 - mae: 38.8745 - val_loss: 5884.4658 - val_mae: 48.9426
# Epoch 5/10
# 12/12 [==============================] - 0s 10ms/step - loss: 4987.9684 - mae: 42.5243 - val_loss: 5939.5303 - val_mae: 48.8798
# Epoch 6/10
# 12/12 [==============================] - 0s 11ms/step - loss: 4803.9141 - mae: 39.5333 - val_loss: 5955.3838 - val_mae: 48.9492
# Epoch 7/10
# 12/12 [==============================] - 0s 10ms/step - loss: 4384.6757 - mae: 39.0261 - val_loss: 5829.7715 - val_mae: 48.7116
# Epoch 8/10
# 12/12 [==============================] - 0s 11ms/step - loss: 5130.6664 - mae: 41.9085 - val_loss: 5813.1675 - val_mae: 48.5242
# Epoch 9/10
# 12/12 [==============================] - 0s 9ms/step - loss: 4397.3201 - mae: 39.4858 - val_loss: 6065.3750 - val_mae: 48.8543
# Epoch 10/10
# 12/12 [==============================] - 0s 11ms/step - loss: 4959.9204 - mae: 42.0494 - val_loss: 5682.0161 - val_mae: 48.5555
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_14 (InputLayer)        [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_27 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 384)               0
# _________________________________________________________________
# dense_52 (Dense)             (None, 128)               49280
# _________________________________________________________________
# dense_53 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_54 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_55 (Dense)             (None, 1)                 33
# =================================================================
# Total params:
15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_30 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_31 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 384)               0
# _________________________________________________________________
# dense_60 (Dense)             (None, 128)               49280
# _________________________________________________________________
# dense_61 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_62 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_63 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 23ms/step - loss: 13063.9832 - mae: 85.0366 - val_loss: 8437.6113 - val_mae: 67.8867
# Epoch 2/10
# 12/12 [==============================] - 0s 9ms/step - loss: 8237.5077 - mae: 64.0131 - val_loss: 6296.2964 - val_mae: 62.3006
# Epoch 3/10
# 12/12 [==============================] - 0s 8ms/step - loss: 6660.2416 - mae: 61.5674 - val_loss: 5779.8433 - val_mae: 56.4660
# Epoch 4/10
# 12/12 [==============================] - 0s 10ms/step - loss: 6777.7000 - mae: 58.7571 - val_loss: 5858.7285 - val_mae: 57.2375
# Epoch 5/10
# 12/12 [==============================] - 0s 9ms/step - loss: 6186.2850 - mae: 56.5247 - val_loss: 5917.6782 - val_mae: 57.0914
# Epoch 6/10
# 12/12 [==============================] - 0s 11ms/step - loss: 6791.9678 - mae: 57.3254 - val_loss: 5860.9673 - val_mae: 56.4643
# Epoch 7/10
# 12/12 [==============================] - 0s 9ms/step - loss: 6655.0074 - mae: 57.7445 - val_loss: 5944.3999 - val_mae: 57.1481
# Epoch 8/10
# 12/12 [==============================] - 0s 12ms/step - loss: 7094.8216 - mae: 60.1787 - val_loss: 5841.0039 - val_mae: 56.4443
# Epoch 9/10
# 12/12 [==============================] - 0s 9ms/step - loss: 6629.9128 - mae: 58.2240 - val_loss: 5874.2275 - val_mae: 56.6696
# Epoch 10/10
# 12/12 [==============================] - 0s 10ms/step - loss: 6562.6631 - mae: 57.9559 - val_loss: 5810.4155 - val_mae: 56.1676
# Model: "model_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_17 (InputLayer)        [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_32 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_33 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 384)               0
# _________________________________________________________________
# dense_64 (Dense)             (None, 128)               49280
# _________________________________________________________________
# dense_65 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_66 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_67 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#

# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_32 (InputLayer)        [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_62 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_63 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_31 (Flatten)         (None, 384)               0
# _________________________________________________________________
# dense_124 (Dense)            (None, 128)               49280
# _________________________________________________________________
# dense_125 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_126 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_127 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 28ms/step - loss: 282808.7596 - mae: 350.1134 - val_loss: 226741.0625 - val_mae: 312.2780
# Epoch 2/10
# 12/12 [==============================] - 0s 10ms/step - loss: 198880.8834 - mae: 298.4502 - val_loss: 187143.1875 - val_mae: 304.6295
# Epoch 3/10
# 12/12 [==============================] - 0s 10ms/step - loss: 149895.1490 - mae: 255.6595 - val_loss: 157041.3906 - val_mae: 257.9086
# Epoch 4/10
# 12/12 [==============================] - 0s 12ms/step - loss: 132792.8371 - mae: 226.6275 - val_loss: 141790.4062 - val_mae: 245.1648
# Epoch 5/10
# 12/12 [==============================] - 0s 11ms/step - loss: 114939.1022 - mae: 204.1378 - val_loss: 134961.3125 - val_mae: 236.1665
# Epoch 6/10
# 12/12 [==============================] - 0s 11ms/step - loss: 115006.3041 - mae: 208.7506 - val_loss: 128121.7344 - val_mae: 227.0329
# Epoch 7/10
# 12/12 [==============================] - 0s 12ms/step - loss: 116178.5823 - mae: 206.9785 - val_loss: 125243.3750 - val_mae: 222.5286
# Epoch 8/10
# 12/12 [==============================] - 0s 11ms/step - loss: 115792.0132 - mae: 208.4841 - val_loss: 125217.0234 - val_mae: 224.9901
# Epoch 9/10
# 12/12 [==============================] - 0s 11ms/step - loss: 127611.7332 - mae: 229.5727 - val_loss: 121646.9844 - val_mae: 217.2274
# Epoch 10/10
# 12/12 [==============================] - 0s 11ms/step - loss: 105794.7825 - mae: 199.8120 - val_loss: 121178.1953 - val_mae: 216.2221
# Model: "model_32"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_33 (InputLayer)        [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_64 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_65 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_32 (Flatten)         (None, 384)               0
# _________________________________________________________________
# dense_128 (Dense)            (None, 128)               49280
# _________________________________________________________________
# dense_129 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_130 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_131 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 27ms/step - loss: 9311.6784 - mae: 73.1322 - val_loss: 3750.9534 - val_mae: 50.0565
# Epoch 2/10
# 12/12 [==============================] - 0s 11ms/step - loss: 4457.3622 - mae: 52.6384 - val_loss: 3524.0945 - val_mae: 49.0580
# Epoch 3/10
# 12/12 [==============================] - 0s 11ms/step - loss: 4832.8690 - mae: 55.0035 - val_loss: 3328.8840 - val_mae: 47.0107
# Epoch 4/10

# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_35 (InputLayer)        [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_68 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_69 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_34 (Flatten)         (None, 384)               0
# _________________________________________________________________
# dense_136 (Dense)            (None, 128)               49280
# _________________________________________________________________
# dense_137 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_138 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_139 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 26ms/step - loss: 136869.3864 - mae: 276.9621 - val_loss: 101419.3750 - val_mae: 223.9945
# Epoch 2/10
# 12/12 [==============================] - 0s 11ms/step - loss: 64652.2626 - mae: 194.4677 - val_loss: 97119.0000 - val_mae: 219.6140
# Epoch 3/10
# 12/12 [==============================] - 0s 12ms/step - loss: 63171.9026 - mae: 181.0898 - val_loss: 95860.3906 - val_mae: 216.3210
# Epoch 4/10
# 12/12 [==============================] - 0s 12ms/step - loss: 55296.5775 - mae: 167.7469 - val_loss: 92236.0156 - val_mae: 212.8765
# Epoch 5/10
# 12/12 [==============================] - 0s 10ms/step - loss: 54125.6764 - mae: 168.5088 - val_loss: 91771.6797 - val_mae: 210.8197
# Epoch 6/10
# 12/12 [==============================] - 0s 10ms/step - loss: 51665.1740 - mae: 163.8969 - val_loss: 91911.9766 - val_mae: 210.1585
# Epoch 7/10
# 12/12 [==============================] - 0s 11ms/step - loss: 56283.6581 - mae: 168.2296 - val_loss: 91120.9766 - val_mae: 209.2274
# Epoch 8/10
# 12/12 [==============================] - 0s 11ms/step - loss: 54373.3005 - mae: 164.6791 - val_loss: 91793.5234 - val_mae: 209.0374
# Epoch 9/10
# 12/12 [==============================] - 0s 11ms/step - loss: 61700.6743 - mae: 177.0233 - val_loss: 91272.4531 - val_mae: 208.3893
# Epoch 10/10
# 12/12 [==============================] - 0s 11ms/step - loss: 53038.4991 - mae: 160.9723 - val_loss: 90740.8047 - val_mae: 208.0318
# Model: "model_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_36 (InputLayer)        [(None, 3, 1)]            0
# _________________________________________________________________
# conv1d_70 (Conv1D)           (None, 3, 64)             192
# _________________________________________________________________
# conv1d_71 (Conv1D)           (None, 3, 128)            16512
# _________________________________________________________________
# flatten_35 (Flatten)         (None, 384)               0
# _________________________________________________________________
# dense_140 (Dense)            (None, 128)               49280
# _________________________________________________________________
# dense_141 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_142 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_143 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 76,353
# Trainable params: 76,353
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 12/12 [==============================] - 1s 27ms/step - loss: 42579.0051 - mae: 162.4873 - val_loss: 26275.4688 - val_mae: 116.1758
# Epoch 2/10
# 12/12 [==============================] - 0s 11ms/step - loss: 24314.3101 - mae: 111.4150 - val_loss: 19698.0781 - val_mae: 114.5358
# Epoch 3/10
# 12/12 [==============================] - 0s 11ms/step - loss: 20078.9809 - mae: 107.6423 - val_loss: 18545.9102 - val_mae: 105.9430
# Epoch 4/10
# 12/12 [==============================] - 0s 13ms/step - loss: 19347.7255 - mae: 103.4556 - val_loss: 18833.0137 - val_mae: 105.6713
# Epoch 5/10
# 12/12 [==============================] - 0s 12ms/step - loss: 18294.7505 - mae: 99.3593 - val_loss: 18802.1406 - val_mae: 108.7579
# Epoch 6/10
# 12/12 [==============================] - 0s 11ms/step - loss: 15987.9816 - mae: 94.6005 - val_loss: 18765.2871 - val_mae: 106.4177
# Epoch 7/10
# 12/12 [==============================] - 0s 11ms/step - loss: 17902.7643 - mae: 98.6963 - val_loss: 18630.9766 - val_mae: 107.7594
# Epoch 8/10
# 12/12 [==============================] - 0s 11ms/step - loss: 18293.7790 - mae: 99.0799 - val_loss: 18625.7090 - val_mae: 106.1157
# Epoch 9/10
# 12/12 [==============================] - 0s 13ms/step - loss: 17286.1385 - mae: 95.9203 - val_loss: 18557.5117 - val_mae: 107.1528
# Epoch 10/10
# 12/12 [==============================] - 0s 11ms/step - loss: 17774.6973 - mae: 97.7749 - val_loss: 18552.5898 - val_mae: 105.8740

# %%
subdivs
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
meanerror
# Out:
# array([140.4678507 , 199.28770968, 109.12406223,  94.3462306 ,
#        128.72484457,  77.49932806,  81.35422742,  67.86587383,
#         77.17628137,  61.79250835,  62.64865462,  88.31259251,
#         40.20679799,  46.87334736,  66.61765539,  57.08613747,
#         28.17995848,  41.28195253,  63.45461393,  78.16995787,
#         80.97948572,  50.93588132, 200.61164137,  54.52411525,
#         60.60954418,  64.22243438,  75.99868872,  64.00701032,
#         60.46937416,  50.05342925,  54.359456  , 185.69336385,
#         49.22969688,  61.56358943, 189.81332926, 104.37353324])

# %%
import numpy as np
meanerror = np.array(mean_error)
